# %%
from obspy import UTCDateTime

# %%
t1 = UTCDateTime('1988/03/17 00:00:00')

# %%
t1
# Out:
# 1988-03-17T00:00:00.000000Z

# %%
t1+86399.99
# Out:
# 1988-03-17T23:59:59.990000Z

# %%
t2 = UTCDateTime('1988/03/18 00:00:00')

# %%
t2-t1
# Out:
# 86400.0

# %%
import timeutils

# %%
starts, stops = timeutils.createTimeChunks(t1, t2, 3600, prsc=.01, verbose=True)
# Out:
# >>> Splitting time period into smaller chunks...
# >>> New chunk : 1988-03-17T00:00:00.000000Z to 1988-03-17T00:59:59.990000Z
# >>> New chunk : 1988-03-17T01:00:00.000000Z to 1988-03-17T01:59:59.990000Z
# >>> New chunk : 1988-03-17T02:00:00.000000Z to 1988-03-17T02:59:59.990000Z
# >>> New chunk : 1988-03-17T03:00:00.000000Z to 1988-03-17T03:59:59.990000Z
# >>> New chunk : 1988-03-17T04:00:00.000000Z to 1988-03-17T04:59:59.990000Z
# >>> New chunk : 1988-03-17T05:00:00.000000Z to 1988-03-17T05:59:59.990000Z
# >>> New chunk : 1988-03-17T06:00:00.000000Z to 1988-03-17T06:59:59.990000Z
# >>> New chunk : 1988-03-17T07:00:00.000000Z to 1988-03-17T07:59:59.990000Z
# >>> New chunk : 1988-03-17T08:00:00.000000Z to 1988-03-17T08:59:59.990000Z
# >>> New chunk : 1988-03-17T09:00:00.000000Z to 1988-03-17T09:59:59.990000Z
# >>> New chunk : 1988-03-17T10:00:00.000000Z to 1988-03-17T10:59:59.990000Z
# >>> New chunk : 1988-03-17T11:00:00.000000Z to 1988-03-17T11:59:59.990000Z
# ...
