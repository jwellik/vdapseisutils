# %% [markdown]
# # Volcano Map Figure

# %% [markdown]
# ### USER PARRAMETERS

# %% [raw]
# # set figure and axis dimensions
# # define and set margins
# fig_width_in = fig_width_in
# fig_height_in = fig_heigh_in
#
# # Figure/Axis dimensions (inches)
# top_margin = top_margin
#
# # map position (inches)
# mWin = fig_width_in/3.75 # ~1.75
# mHin = mWin
# mmL = 0.0 # map margin left
# mmB = bottom_margin # map margin bottom
# mmT = top_margin
#
# # map colorbar position (inches)
# cbL = mmL # colorbar left
# cbB = 0.5 # coloarbar bottom
# cbW = mWin
# cbH = 0.2
#
# mtsgap = 0.7 # gap betwen map & timeseries
#
# # timeseries position (inches)
# tsWin = 3.25 # time-series width (inches)
# tsHin = 1.5 # time-series height
# tsmL = mWin + mtsgap
# tsmT = top_margin
# tsmB = fig_height_in - tsHin - tsmT
#
# # timeseries legend position (inches)
# legL = tsmL
# legB = 0.05
# legW = tsWin
# legH = cbH
#
# # Axis bounds (l,b,w,h)
# # Convert position from inches to relative-figure location
# #a = list(np.array([1, 2, 3, 4])/5)
# #a
# map_bounds    = [mmL/fig_width_in, mmB/fig_height_in, mWin/fig_width_in, mHin/fig_height_in]
# ts_bounds     = [tsmL/fig_width_in, tsmB/fig_height_in, tsWin/fig_width_in, tsHin/fig_height_in]
# cbar_bounds   = [cbL/fig_width_in, cbB/fig_height_in, cbW/fig_width_in, cbH/fig_width_in]
# legend_bounds = [legL/fig_width_in, legB/fig_height_in, legW/fig_width_in, legH/fig_width_in]
#
#
# # create figure
# # https://stackoverflow.com/questions/46105333/creating-multiple-y-axis-on-both-sides
# fig = plt.figure(figsize=[fig_width_in,fig_height_in])
#
#
# ######## DEFINE MAP AXES ##################################
# axm = fig.add_subplot(2,1,1, projection=mercator)
# axm.set_position(map_bounds)

# %%
import matplotlib.pyplot as plt

# Figure Dimensions

fig_width_in = 5.5
fig_height_in = fig_width_in
top_margin_in = 1
bottom_margin_in = 1
left_margin_in = 1
right_margin_in = 1
gap_in = 0.5

# Map
mheight_in = 3
mwidth_in = 3
mleft_in = 1
mbottom_in = fig_width_in - mheight_in
map_bounds = [mleft_in/fig_width_in, mbottom_in/fig_height_in, mwidth_in/fig_width_in, mheight_in/fig_height_in]

# Cross Section Profile
mleft_in = mleft_in
mwidth_in = mwidth_in
mheight_in = 1
mbottom_in = mbottom_in - gap_in - mheight_in
xs_bounds = [mleft_in/fig_width_in, mbottom_in/fig_height_in, mwidth_in/fig_width_in, mheight_in/fig_height_in]

# Colorbar Profile
mleft_in = 1+3+gap_in
mbottom_in = mbottom_in
mheight_in = 3+gap_in+mheight_in
mwidth_in = 0.25
cb_bounds = [mleft_in/fig_width_in, mbottom_in/fig_height_in, mwidth_in/fig_width_in, mheight_in/fig_height_in]

# %%
fig = plt.figure(figsize=(7,7))
axm = fig.add_subplot(3,1,1)
axm.set_position(map_bounds)

ax1 = fig.add_subplot(3,1,2)
ax1.set_position(xs_bounds)

ax2 = fig.add_subplot(3,1,3)
ax2.set_position(cb_bounds)

fig.show()
# Out:
# <ipython-input-2-192a36c03b05>:11: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
map_bounds
# Out:
# [0.18181818181818182,
#  0.45454545454545453,
#  0.5454545454545454,
#  0.5454545454545454]

# %%
xs_bounds
# Out:
# [0.18181818181818182,
#  0.18181818181818182,
#  0.5454545454545454,
#  0.18181818181818182]

# %%
cb_bounds
# Out:
# [0.8181818181818182,
#  0.18181818181818182,
#  0.045454545454545456,
#  0.8181818181818182]

# %%
1/0.18181818181818/1
# Out:
# 5.500000000000055

# %%
1/.45454545454545
# Out:
# 2.200000000000022

# %%
1/.545454545454545
# Out:
# 1.833333333333335

# %%
1/.81818181818182
# Out:
# 1.2222222222222194
