# %% [markdown]
# # Basic Waveform Plotting

# %% [raw]
# We will plot the waveforms using methods in waveformutils.plotting.swarmmpl. We will use three methods:
#
#  - swarmwg    # Plots the spectrogram (g) with the waveform (w) above it
#  - swarmw     # Plots the waveform only
#  - swarmg     # Plots the spectrogram only
#
# "w" and "g" are the hotkeys in Swarm to toggle between waveforms and spectrograms, respectively.
#
# These methods are designed to give a simple, well-formatted display of a Stream object. A Matplotlib Figure object is returned in case you want to customize anything afterward.
#
# Data are retrieved using the DataSource class. See other notebooks for examples of full capabilities. You must have internet access to run this example.

# %%
import matplotlib.pyplot as plt

from waveformutils.DataSource import DataSource
from waveformutils.plotting.swarmmpl import swarmwg, swarmw, swarmg
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/w8/dq7gt3kd6pl03hgc_3tzh9_jj1pwxz/T/ipykernel_48687/2387377219.py in <module>
# ----> 1 from waveformutils.DataSource import DataSource
#       2 from waveformutils.plotting.swarmmpl import swarmwg, swarmw, swarmg
#
# ~/PYTHON/vdapseisutils/waveformutils/DataSource.py in <module>
#       1 import os
#       2
# ----> 3 from vdapseisutils.waveformutils.datasource.fileutils import get_all_files, get_filelist
#       4
#       5
#
# ModuleNotFoundError: No module named 'vdapseisutils'

# %% [markdown]
# ## Pavlof Explosion (swarmwg)

# %%
ds = DataSource("pubavo1.wr.usgs.gov:16022")
nslc_list = ["AV.PV6A.--.SHZ", "AV.PS4A.--.BHZ", "AV.PVV.--.SHZ"]  # Pavlof
tstart = "2021/11/08 03:10"
tend = "2021/11/08 03:50"
st = ds.getWaveforms(nslc_list, tstart, tend, verbose=False, create_empty_trace=True)
fig = swarmwg(st, wave_color="k", cmap="magma_r")  # These are the default values
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/w8/dq7gt3kd6pl03hgc_3tzh9_jj1pwxz/T/ipykernel_48687/296449690.py in <module>
# ----> 1 ds = DataSource("pubavo1.wr.usgs.gov:16022")
#       2 nslc_list = ['AV.PV6A.--.SHZ', 'AV.PS4A.--.BHZ', 'AV.PVV.--.SHZ']  # Pavlof
#       3 tstart = '2021/11/08 03:10'
#       4 tend = '2021/11/08 03:50'
#       5 st = ds.getWaveforms(nslc_list, tstart, tend, verbose=False, create_empty_trace=True)
#
# NameError: name 'DataSource' is not defined

# %% [markdown]
# ## Pavlof Gliding Tremor (swarmg)

# %%
ds = DataSource("pubavo1.wr.usgs.gov:16022")
nslc_list = ["AV.PV6A.--.SHZ", "AV.PS4A.--.BHZ", "AV.PVV.--.SHZ"]  # Pavlof
tstart = ""
tend = ""
st = ds.getWaveforms(nslc_list, tstart, tend, verbose=False, create_empty_trace=True)
fig = swarmwg(st, cmap="magma_r")  # These are the default values
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/w8/dq7gt3kd6pl03hgc_3tzh9_jj1pwxz/T/ipykernel_48687/553963802.py in <module>
# ----> 1 ds = DataSource("pubavo1.wr.usgs.gov:16022")
#       2 nslc_list = ["AV.PV6A.--.SHZ", "AV.PS4A.--.BHZ", "AV.PVV.--.SHZ"]  # Pavlof
#       3 tstart = ""
#       4 tend = ""
#       5 st = ds.getWaveforms(nslc_list, tstart, tend, verbose=False, create_empty_trace=True)
#
# NameError: name 'DataSource' is not defined

# %% [markdown]
# ## Pavlof LPs (swarmw)

# %%
ds = DataSource("pubavo1.wr.usgs.gov:16022")
nslc_list = ["AV.PV6A.--.SHZ", "AV.PS4A.--.BHZ", "AV.PVV.--.SHZ"]  # Pavlof
tstart = ""
tend = ""
st = ds.getWaveforms(nslc_list, tstart, tend, verbose=False, create_empty_trace=True)
fig = swarmwg(st, cmap="magma_r")  # These are the default values
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/w8/dq7gt3kd6pl03hgc_3tzh9_jj1pwxz/T/ipykernel_48687/553963802.py in <module>
# ----> 1 ds = DataSource("pubavo1.wr.usgs.gov:16022")
#       2 nslc_list = ["AV.PV6A.--.SHZ", "AV.PS4A.--.BHZ", "AV.PVV.--.SHZ"]  # Pavlof
#       3 tstart = ""
#       4 tend = ""
#       5 st = ds.getWaveforms(nslc_list, tstart, tend, verbose=False, create_empty_trace=True)
#
# NameError: name 'DataSource' is not defined
